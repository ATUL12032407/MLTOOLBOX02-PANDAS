# %%
#matplotlib, seaborn >>important from interview point of view, plotly >> interactive, bokeh

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#plt.style.use('classic')\
#http://tonysyu.github.io/raw_content/matplotlib-style-gallery/gallery.html

# %%
x =np.random.rand(50)
y =np.random.rand(50)

# %%
x
# Out:
# array([0.14483094, 0.92337549, 0.00183179, 0.21356488, 0.19962175,
#        0.41092973, 0.38778283, 0.48050339, 0.18626225, 0.02900461,
#        0.04451333, 0.38706311, 0.3823292 , 0.31752535, 0.92215252,
#        0.72532845, 0.2742662 , 0.8894013 , 0.35686597, 0.59678233,
#        0.62392155, 0.09278374, 0.62283258, 0.97591821, 0.7014067 ,
#        0.96406962, 0.343588  , 0.24272439, 0.10840722, 0.24464416,
#        0.63763411, 0.80061903, 0.06931723, 0.09932264, 0.46303788,
#        0.74715396, 0.6510455 , 0.60640518, 0.11834346, 0.35220561,
#        0.48705256, 0.73667128, 0.45174604, 0.99379918, 0.82087033,
#        0.35438905, 0.16389722, 0.86335639, 0.84463129, 0.96054089])

# %%
y
# Out:
# array([0.87332177, 0.74428087, 0.54410166, 0.67221589, 0.57888963,
#        0.92460319, 0.18971034, 0.73211172, 0.75314668, 0.05986515,
#        0.04254894, 0.45804612, 0.05043513, 0.31042885, 0.66904122,
#        0.17880541, 0.70472516, 0.83762561, 0.81077429, 0.0284323 ,
#        0.64278563, 0.89813586, 0.79723942, 0.79495191, 0.11252834,
#        0.54182602, 0.92205917, 0.97487557, 0.03274612, 0.37311759,
#        0.78442435, 0.05598608, 0.00205332, 0.2715912 , 0.76501801,
#        0.65981462, 0.01788429, 0.55962455, 0.46553527, 0.91883999,
#        0.18698873, 0.89251251, 0.92028283, 0.57065666, 0.73655586,
#        0.95494788, 0.88639563, 0.5577793 , 0.98908869, 0.2423985 ])

# %%
plt.scatter(x,y)

# %%
df = pd.DataFrame(np.random.randn(1000),columns =['data'],index=pd.date_range('2020/04/21',periods=1000))

# %%
df
# Out:
#                 data
# 2020-04-21  1.213181
# 2020-04-22  0.923118
# 2020-04-23 -0.136004
# 2020-04-24 -0.020628
# 2020-04-25  0.040397
# ...              ...
# 2023-01-11  1.812343
# 2023-01-12 -0.350278
# 2023-01-13  0.652100
# 2023-01-14 -0.402451
# 2023-01-15 -0.546863
#
# [1000 rows x 1 columns]

# %%
df1 =pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df1.plot(figsize =(20 ,8))
# Out:
# <Axes: >

# %%
df.plot(figsize =(20 ,8))
# Out:
# <Axes: >

# %%
x = np.linspace(0,10,100)

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
plt.plot(x)

# %%
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x))

# %%
plt.plot(x,np.sin(x),'-')

# %%
plt.plot(x,np.sin(x),'--')

# %%
plt.plot(x,np.sin(x),'.-')

# %%
plt.plot(x,np.sin(x),':')

# %%
plt.figure()
plt.subplot(1,2,1)
plt.plot(x,np.sin(x))

plt.subplot(1,2,2)
plt.plot(x,np.cos(x))

# %%
plt.figure()
plt.subplot(2,2,1)
plt.plot(x,np.sin(x))

plt.subplot(2,2,2)
plt.plot(x,np.cos(x))

# %%
plt.figure()
plt.subplot(2,2,1)
plt.plot(x,np.sin(x))

plt.subplot(2,2,2)
plt.plot(x,np.cos(x))

plt.figure()
plt.subplot(2,2,3)
plt.plot(x,np.tan(x))

plt.subplot(2,2,4)
plt.plot(x,np.cos(x+1))

# %%
plt.show()

# %%
plt.figure()
plt.subplot(2,1,1)
plt.plot(x,np.sin(x))

plt.subplot(2,1,2)
plt.plot(x,np.cos(x))

# %%
plt.plot(x,np.sin(x-0),color ='red')
plt.plot(x,np.sin(x-1),color ='green')
plt.plot(x,np.sin(x-2),color ='y')
plt.plot(x,np.sin(x-3),color ='b')
plt.plot(x,np.sin(x-4),color =(1.0,0.5,0))

# RGB Format

# %%
plt.plot(x,np.sin(x-0),color ='b')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.show()

# %%
plt.plot(x,np.sin(x-0),color ='b')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.axis('equal')
plt.show()

# %%
plt.plot(x,np.sin(x-0),color ='b')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.grid(True)
plt.axis('equal')
plt.show()

# %%
plt.plot(x,np.sin(x-0),color ='b')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.grid(True)
plt.title('This is sin plot before real dataset to understand basic syntax')
plt.axis('equal')
plt.show()

# %%
plt.plot(x,np.sin(x-0),color ='b')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.grid(True)
plt.title('This is sin plot before real dataset to understand basic syntax')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.axis('equal')
plt.show()

# %%
plt.plot(x,np.sin(x-0),color ='b',label = 'Sinx')
plt.plot(x,np.cos(x-0),color ='r',label = 'Cosx')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.grid(True)
plt.title('This is sin plot before real dataset to understand basic syntax')
plt.xlabel('x axis')
plt.ylabel('y axis')
#plt.axis('equal')
plt.legend()
plt.show()

# %%
# Histogram

data = np.random.randn(1000)
plt.hist(data)
plt.show()
# bins are the smallest unit in which u are dividing the data. By default there will be 10 bins created by histogram.

# %%
data

##For continuous data we will make histogram or distribution.
## For discrete it is bar plot.
# Out:
# array([ 2.78552344e-01,  3.13677045e-01, -8.75550955e-01, -9.71126287e-01,
#        -6.47255029e-01,  3.21890814e+00,  5.69739791e-02, -6.71278943e-01,
#         3.27089839e-01,  6.04024322e-01, -3.59810291e-02,  1.27356465e+00,
#        -1.04731869e+00,  7.76904435e-02, -7.09975269e-01,  3.57667192e-01,
#         6.51015960e-01,  6.21691502e-01,  6.97053465e-01, -2.00381843e-01,
#         5.12327914e-01,  9.75387464e-02, -3.66550168e-01,  1.41513629e+00,
#         1.23430508e+00, -8.66532237e-01, -1.01269792e+00, -7.68689881e-01,
#        -1.02985968e+00, -6.52087058e-01, -1.13715221e+00, -9.37799761e-02,
#        -9.74982769e-02, -7.94763425e-01, -1.12601940e+00, -6.52975711e-01,
#         3.26010255e-01,  1.63971451e+00, -1.01796469e+00,  8.27598627e-01,
#        -1.40441841e+00,  1.09893881e+00,  4.03030453e-01,  2.03848110e-01,
#         5.97169744e-01, -1.23383319e+00,  1.23721940e+00, -4.97760451e-01,
# ...

# %%
data = np.random.randn(1000)
plt.hist(data ,bins =20)
plt.show()

# %%
data = np.random.randn(1000)
plt.hist(data ,bins =20 ,histtype ='step')
plt.show()

# %%
data = np.random.randn(1000)
plt.hist(data, bins=20, histtype='stepfilled')  # Change 'step' to 'stepfilled'
plt.show()

# %%
data = np.random.randn(1000)
plt.hist(data ,bins =20 ,histtype ='barstacked',color ='r',stacked =True)
plt.show()

# %%
data = np.random.randn(1000)
plt.hist(data ,bins =20 ,histtype ='bar',color ='g')
plt.show()

# %%
data = np.random.randn(1000)
plt.hist(data ,bins =20 ,histtype ='step',color ='g')
plt.show()

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
y
# Out:
# array([0.98559248, 0.64017594, 0.77256445, 0.86439266, 0.72549086,
#        0.12057718, 0.44834272, 0.52290947, 0.21627666, 0.19766813,
#        0.44064949, 0.39635903, 0.21769318, 0.28199174, 0.91364678,
#        0.86599548, 0.67870907, 0.64780668, 0.01977395, 0.49890249,
#        0.10389346, 0.71556232, 0.83151499, 0.36896614, 0.30654661,
#        0.63484417, 0.85061362, 0.18095495, 0.9208503 , 0.17619764,
#        0.49752102, 0.63190397, 0.70975423, 0.32338932, 0.49852995,
#        0.748247  , 0.02453531, 0.42749421, 0.40012596, 0.61932704,
#        0.61267257, 0.01878903, 0.14586517, 0.51169843, 0.34296722,
#        0.39914197, 0.93856162, 0.12921297, 0.92599049, 0.37518441])

# %%
x =np.random.rand(50)
y =np.random.rand(50)
plt.figure(figsize=(6,2))
plt.scatter(x,y , c='r' ,alpha = .9, marker ="*")
plt.xlabel('x')
plt.ylabel('y')
plt.title('scatter plot')
plt.show()
# Range of alpha between 0 and 1
# Higher the value of alpha changes the intensity of colour.
# marker represents the format of scattering.

# %%
# Why are we making scatter plot ?

# To understand the variation of data we make a scatter plot.

# %%
x =["a","b","c","d"]
y=[4,6,1,2]

# %%
x
# Out:
# ['a', 'b', 'c', 'd']

# %%
y
# Out:
# [4, 6, 1, 2]

# %%
# It will use bar plot as itis categoricaal data.

# %%
plt.figure(figsize =(6,3))
plt.bar(x,y ,color='r')
plt.show()

# %%
plt.figure(figsize =(6,3))
plt.bar(x,y ,color='g')
plt.show()

# %%
plt.figure(figsize =(6,3))
plt.bar(x,y ,color='#FF5733')
plt.show()

# %%
plt.figure(figsize =(6,3))
plt.bar(x,y ,color='#FF5733')
plt.title(  'This is my Bar plot')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
# Use only standard blue colours in industry.

# %%
data =[1,2,3,3,3,3,4,5,6,7,8]
plt.hist(data)
# Out:
# (array([1., 1., 4., 0., 1., 1., 0., 1., 1., 1.]),
#  array([1. , 1.7, 2.4, 3.1, 3.8, 4.5, 5.2, 5.9, 6.6, 7.3, 8. ]),
#  <BarContainer object of 10 artists>)

# %%
# 3-d plot
x= np.random.rand(20)
y= np.random.rand(20)
z= np.random.rand(20)
fig = plt.figure()
ax = fig.add_subplot(projection ='3d')
plt.show()

# %%
#pie chart

langs = ['C', 'Python', 'Java']
students = [20, 100, 40]

plt.pie(students, labels = langs, autopct = '%1.1f%%')
plt.title("Pie chart")
plt.show()

# %%
my_explode = (0.0, 0.1, 0.1)

langs = ['C', 'Python', 'Java']
students = [20, 100, 40]

plt.pie(students, labels = langs, autopct = '%1.1f%%', explode = my_explode, shadow =  True)
plt.title("Pie chart")
plt.show()

# %%
x= np.random.rand(20)
y= np.random.rand(20)
z= np.random.rand(20)
fig = plt.figure()
ax = fig.add_subplot(111,projection ='3d')
ax.scatter(x,y,z, c='#FF5733', alpha = .9)
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.show()

# %%
x
# Out:
# array([0.8238453 , 0.09602891, 0.06117642, 0.68965491, 0.79227123,
#        0.72805237, 0.34385869, 0.70552845, 0.38050759, 0.0414848 ,
#        0.59274492, 0.68992275, 0.29340577, 0.53369662, 0.35896695,
#        0.37204078, 0.05566933, 0.58445899, 0.88316029, 0.53032733])

# %%
y
# Out:
# array([0.57664638, 0.49453414, 0.56791078, 0.04536348, 0.04514794,
#        0.16003279, 0.23225575, 0.7826937 , 0.94663648, 0.13477139,
#        0.38535844, 0.62250626, 0.8518842 , 0.10109145, 0.96272882,
#        0.90143071, 0.28564596, 0.5789692 , 0.567862  , 0.29145745])

# %%
z
# Out:
# array([0.44106825, 0.81997531, 0.68806005, 0.30848923, 0.27166482,
#        0.00805414, 0.24396102, 0.14416417, 0.499233  , 0.03037486,
#        0.19890702, 0.83857334, 0.13020842, 0.66663177, 0.51645064,
#        0.93541694, 0.30452259, 0.79170471, 0.97475705, 0.58674756])

# %%
import pandas as pd

data = pd.read_csv("/content/Bank_churn.csv")
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
data.plot.scatter(x = 'Age', y = "Balance")

#insights
# Where is maximum concentration of the data ?
#maximum concentration >> 25-50
# Which age group has the maximum amount ?
#maximum >>  40
#min>>0 because it is present in all of the age group
# Out:
# <Axes: xlabel='Age', ylabel='Balance'>

# %%
# Age distribution
plt.title("Age distribution")
plt.hist(data['Age'] ,color ='r')
plt.show()

# Balance distribution
plt.title("Balance distribution")
plt.hist(data['Balance'] ,color ='r')
plt.show()

# %%
data.boxplot(column = 'Balance')
# Out:
# <Axes: >

# %%
plt.violinplot(data['Balance'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x7bdd7a217d60>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x7bdd7a214f40>,
#  'cmins': <matplotlib.collections.LineCollection at 0x7bdd7a040340>,
#  'cbars': <matplotlib.collections.LineCollection at 0x7bdd7a0408e0>}

# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sns.histplot(tips['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.distplot(tips['total_bill'])
# Out:
# <ipython-input-237-057ee9cdc291>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['total_bill'])
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# Kernal Density estimator

# %%
sns.displot(tips['total_bill'])

# %%
sns.displot(tips['total_bill'],kde =False , bins = 30)

# %%
sns.scatterplot(x = 'total_bill', y = 'tip', data = tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x = tips.total_bill, y=tips.tip, data = tips, hue= 'smoker')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips , hue='smoker')

# %%
# Hue is nothing but a parameter where u can differentiate diferent types from data set.

# %%
sns.relplot(x = tips.total_bill, y=tips.tip, data = tips, hue = 'size')

# %%
sns.relplot(x = tips.total_bill, y=tips.tip, data = tips, style = 'size')

# %%
sns.relplot(x = tips.total_bill, y=tips.tip, data = tips, style = 'smoker')

# %%
sns.relplot(x = tips.total_bill, y=tips.tip, data = tips, style = 'smoker',hue= 'time')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips)

# %%
sns.barplot(x = 'day' , y='total_bill', data = tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x = 'day', y = 'total_bill', data = tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# !pip install seaborn

# %%
import seaborn as sns

# %%
import seaborn as sns

sns.jointplot(x = 'total_bill', y = 'tip', data = tips)

# %%
sns.jointplot(x = tips.total_bill, y=tips.tip, data = tips, kind="reg")

# %%
sns.jointplot(x = tips.total_bill, y=tips.tip, data = tips, kind="hex")

# %%
sns.jointplot(x = tips.total_bill, y=tips.tip, data = tips, kind="kde") #contour>>meterological

# %%
#  Pairplot >> It will plot all the pairwise relationship of the dataframe.

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips, hue = 'sex')

# %%
sns.pairplot(tips, hue = 'smoker')

# %%
sns.pairplot(tips, hue = 'smoker',palette = 'coolwarm')

# https://seaborn.pydata.org/generated/seaborn.color_palette.html
# https://seaborn.pydata.org/tutorial/color_palettes.html

# %%
#Boxplot >> to know outliers
#1, 2, 3, 4, 5, 100 >>> extreme data, for each day give me outlier for total bill

sns.boxplot(x = 'day', y='total_bill', data=tips, palette = 'rainbow')
# Out:
# <ipython-input-274-3c0cececa337>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'day', y='total_bill', data=tips, palette = 'rainbow')
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data=tips, palette = 'rainbow', orient = 'h')
# Out:
# <Axes: >

# %%
#correlation >> to understand the relationship between

# %%
tips_num = tips[['total_bill', 'tip', 'size']]

# %%
tips_num.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['total_bill'].plot(kind='hist', bins=20, title='total_bill')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['tip'].plot(kind='hist', bins=20, title='tip')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['size'].plot(kind='hist', bins=20, title='size')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
sns.heatmap(tips_num.corr(), annot = True, cmap = 'coolwarm')
# Out:
# <Axes: >

# %%
sns.heatmap(tips_num.corr(), annot = True,)
# Out:
# <Axes: >

# %%
sns.countplot(x = 'sex', data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.lmplot(x = 'total_bill', y='tip', data = tips, height = 20, aspect = 1)

# %%
sns.catplot(x = 'day', y = 'tip', data = tips, kind='swarm')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
